# %%
import os
from torchvision import datasets,transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time
import torchvision.models as models
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
import numpy as np

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### LOAD DATA

# %% [raw]
# # resizing the image from 800*600 to a fixed size
# # these values of mean and std distriubution are from ImageNet , helpful in transfer learning
# #small dataset apply data augmentation to get rich & diverstiy in training samples like contrast,saturation,flip rotation

# %%
image_transform=transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2,contrast=0.2),
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406],std=[0.229,0.224,0.225]), 
])

dataset=datasets.ImageFolder(root="dataset/",transform=image_transform)
print(len(dataset)) 
print(dataset.classes)
num_classes=len(dataset.classes)
num_classes
train_size=int(len(dataset)*0.75) 
val_size=len(dataset)-train_size

train_size,val_size
# Out:
# 2301
# ['F_Breakage', 'F_Crushed', 'F_Normal', 'R_Breakage', 'R_Crushed', 'R_Normal']
# (1725, 576)

# %%
train_dataset,val_dataset=random_split(dataset,[train_size,val_size])

train_loader=DataLoader(train_dataset,batch_size=32,shuffle=True)
val_loader=DataLoader(val_dataset,batch_size=32,shuffle=False)

for images,labels in train_loader:
    print(images.shape)
    print(labels.shape)
    break
# Out:
# torch.Size([32, 3, 224, 224])
# torch.Size([32])

# %%
print(images[0].shape)
images[0].permute(1,2,0).shape
plt.imshow(images[0].permute(1,2,0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# torch.Size([3, 224, 224])

# %% [markdown]
# ### MODEL-1 CNN

# %%
class carclassifierCNN(nn.Module):
    def __init__(self,num_classes):
        super().__init__()
        self.network=nn.Sequential(
        nn.Conv2d(in_channels=3,out_channels=16,kernel_size=(3,3),stride=1,padding=1), #output(16,224*224)
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=(2,2),stride=(2,2)), #output (16,112*112)

        nn.Conv2d(in_channels=16,out_channels=32,kernel_size=(3,3),stride=1,padding=1), #output(32,112*112)
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=(2,2),stride=(2,2)),#output (32,56*56)

        nn.Conv2d(in_channels=32,out_channels=64,kernel_size=(3,3),stride=1,padding=1), #output(64,56*56)
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=(2,2),stride=(2,2)),#output (64,28*28)

        nn.Flatten(),
        nn.Linear(64*28*28,512),
        nn.ReLU(),
        nn.Linear(512,num_classes)
        )
    def forward(self,x):
        x=self.network(x)
        return x

# %%
model=carclassifierCNN(num_classes=num_classes).to(device)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(model.parameters(),lr=0.001)

# %%
values,indices=torch.max(torch.tensor([[10,2,2,6,85,12]]),dim=1)
values,indices
# Out:
# (tensor([85]), tensor([4]))

# %%
def train_model(model,criterion,optimizer,epochs=5):
    start=time.time()
    for epoch in range(epochs):
        model.train()
        running_loss=0.0
        for batch_num,(images,labels) in enumerate(train_loader):
            images,labels=images.to(device),labels.to(device)
            optimizer.zero_grad()
            outputs=model(images)
            loss=criterion(outputs,labels)
            loss.backward()
            optimizer.step()
            if (batch_num+1)%10==0:
                print(f"Batch:{batch_num+1}, Epoch:{epoch+1} ,loss:{loss.item():.2f}")
            
            running_loss+=loss.item()*images.size(0) # total loss of an entire batch
        epoch_loss=running_loss/len(train_loader.dataset)
        print(f"epoch [{epoch+1}/{epochs}], Avg loss:{epoch_loss:.4f}")

        model.eval()
        correct=0
        total=0
        all_labels=[]
        all_predicted=[]
        with torch.no_grad():
            for images,labels in val_loader:
                images,labels=images.to(device),labels.to(device)
                outputs=model(images)
                _,predicted=torch.max(outputs.data,1)
                total+=labels.size(0)
                correct+=(predicted==labels).sum().item()
                all_labels.extend(labels.cpu().numpy())
                all_predicted.extend(predicted.cpu().numpy())
            accuracy=(correct/total)*100
            print(f"Validation Accuracy: {accuracy:.2f} ")
    end=time.time()
    print(f"Execution time :{end-start} seconds")
    return all_labels,all_predicted

# %%
all_labels,all_predictions=train_model(model,criterion,optimizer,epochs=5)
# Out:
# Batch:10, Epoch:1 ,loss:1.78
# Batch:20, Epoch:1 ,loss:1.73
# Batch:30, Epoch:1 ,loss:1.79
# Batch:40, Epoch:1 ,loss:1.73
# Batch:50, Epoch:1 ,loss:1.61
# epoch [1/5], Avg loss:1.8366
# Validation Accuracy: 33.51
# Batch:10, Epoch:2 ,loss:1.53
# Batch:20, Epoch:2 ,loss:1.49
# Batch:30, Epoch:2 ,loss:1.17
# Batch:40, Epoch:2 ,loss:1.41
# Batch:50, Epoch:2 ,loss:1.45
# epoch [2/5], Avg loss:1.4092
# Validation Accuracy: 43.92
# Batch:10, Epoch:3 ,loss:1.26
# Batch:20, Epoch:3 ,loss:1.36
# Batch:30, Epoch:3 ,loss:1.08
# Batch:40, Epoch:3 ,loss:1.21
# Batch:50, Epoch:3 ,loss:0.84
# epoch [3/5], Avg loss:1.1897
# Validation Accuracy: 48.61
# Batch:10, Epoch:4 ,loss:1.09
# Batch:20, Epoch:4 ,loss:1.17
# Batch:30, Epoch:4 ,loss:1.09
# Batch:40, Epoch:4 ,loss:0.87
# Batch:50, Epoch:4 ,loss:1.15
# epoch [4/5], Avg loss:1.0820
# Validation Accuracy: 48.61
# Batch:10, Epoch:5 ,loss:0.80
# Batch:20, Epoch:5 ,loss:1.12
# Batch:30, Epoch:5 ,loss:1.05
# Batch:40, Epoch:5 ,loss:1.11
# Batch:50, Epoch:5 ,loss:0.95
# epoch [5/5], Avg loss:0.9987
# Validation Accuracy: 54.51
# Execution time :412.2678732872009 seconds

# %% [raw]
# Here the training loss was decreasing  , but validation loss is higher as validation  accuracy was lower, hence the model was overfitting
# so applying regularization , ie batch normalization,dropout layer

# %% [markdown]
# ### MODEL-1 CNN WITH REGULARIZATION

# %%
class carclassifierCNN(nn.Module):
    def __init__(self,num_classes):
        super().__init__()
        self.network=nn.Sequential(
        nn.Conv2d(in_channels=3,out_channels=16,kernel_size=(3,3),stride=1,padding=1), #output(16,224*224)
        nn.BatchNorm2d(16),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=(2,2),stride=(2,2)), #output (16,112*112)

        nn.Conv2d(in_channels=16,out_channels=32,kernel_size=(3,3),stride=1,padding=1), #output(32,112*112)
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=(2,2),stride=(2,2)),#output (32,56*56)

        nn.Conv2d(in_channels=32,out_channels=64,kernel_size=(3,3),stride=1,padding=1), #output(64,56*56)
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=(2,2),stride=(2,2)),#output (64,28*28)

        nn.Flatten(),
        nn.Linear(64*28*28,512),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512,num_classes)
        )
    def forward(self,x):
        x=self.network(x)
        return x

# %%
model=carclassifierCNN(num_classes=num_classes).to(device)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(model.parameters(),lr=0.001,weight_decay=1e-4)

# %%
all_labels,all_predictions=train_model(model,criterion,optimizer,epochs=5)
# Out:
# Batch:10, Epoch:1 ,loss:15.94
# Batch:20, Epoch:1 ,loss:3.56
# Batch:30, Epoch:1 ,loss:2.03
# Batch:40, Epoch:1 ,loss:1.44
# Batch:50, Epoch:1 ,loss:1.20
# epoch [1/5], Avg loss:7.1175
# Validation Accuracy: 45.14
# Batch:10, Epoch:2 ,loss:1.55
# Batch:20, Epoch:2 ,loss:1.41
# Batch:30, Epoch:2 ,loss:1.51
# Batch:40, Epoch:2 ,loss:1.35
# Batch:50, Epoch:2 ,loss:1.36
# epoch [2/5], Avg loss:1.3218
# Validation Accuracy: 53.12
# Batch:10, Epoch:3 ,loss:1.60
# Batch:20, Epoch:3 ,loss:0.83
# Batch:30, Epoch:3 ,loss:1.11
# Batch:40, Epoch:3 ,loss:1.19
# Batch:50, Epoch:3 ,loss:1.13
# epoch [3/5], Avg loss:1.2447
# Validation Accuracy: 51.04
# Batch:10, Epoch:4 ,loss:1.20
# Batch:20, Epoch:4 ,loss:1.10
# Batch:30, Epoch:4 ,loss:1.13
# Batch:40, Epoch:4 ,loss:1.34
# Batch:50, Epoch:4 ,loss:1.33
# epoch [4/5], Avg loss:1.1695
# Validation Accuracy: 50.52
# Batch:10, Epoch:5 ,loss:1.36
# Batch:20, Epoch:5 ,loss:0.97
# Batch:30, Epoch:5 ,loss:1.11
# Batch:40, Epoch:5 ,loss:1.31
# Batch:50, Epoch:5 ,loss:1.01
# epoch [5/5], Avg loss:1.1656
# Validation Accuracy: 55.38
# Execution time :460.1469519138336 seconds

# %% [raw]
# despite using batch normalization and droput layer , the validation accuracy doesnt increase it is
# due to less training samples ,so gathering more data for training is time confusing we will
# use transfer learning

# %% [markdown]
# ### Transfer Learning

# %% [raw]
# EfficientNet-B0 trained on ImageNet.
#
# It has:
# Feature extractor (conv + batchnorm layers)
# Original classifier (final fully connected layer for ImageNet classes)
#
# step2 -:
# for param in self.model.parameters():
#     param.requires_grad = False
# at the moment
# Feature extractor → ❄️ frozen
# Original classifier → ❄️ frozen
#
# step 3
# You remove the old (frozen) classifier completely
# 👉 You add a brand new classifier
# self.model.classifier = nn.Sequential(
#     nn.Dropout(0.5),
#     nn.Linear(in_features, num_classes)
# )
#
# in short feature extraction and classification is there in convolution
# we are freezing feature extraction phase and modifying the classifier layer
# classifier layer has FCN and dropout layer

# %%
model=models.efficientnet_b0(weights="DEFAULT")
#print(model)
print(model.classifier[1])
model.classifier[1].in_features
# Out:
# Linear(in_features=1280, out_features=1000, bias=True)
# 1280

# %%
class carclassifierefficientnet(nn.Module):
    def __init__(self,num_classes):
        super().__init__()
        self.model=models.efficientnet_b0(weights="DEFAULT")
        for param in self.model.parameters(): 
            param.requires_grad=False
        in_features=self.model.classifier[1].in_features
        self.model.classifier=nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(in_features,num_classes)
        )
    def forward(self,x):
        x=self.model(x)
        return x

# %% [raw]
# filter(lambda p : p.requires_grad,model.parameters()
# Only the classifier weights are given to the optimizer
# 👉 Frozen layers are ignored completely (no updates, no gradients)

# %%
model=carclassifierefficientnet(num_classes=num_classes).to(device)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(filter(lambda p : p.requires_grad,model.parameters()),lr=0.001,weight_decay=1e-4)

# %%
all_labels,all_predictions=train_model(model,criterion,optimizer,epochs=5)

# %%
accuarcy just imporved slightly

# %% [markdown]
# ### ResNet  model

# %%
class carclassifierresnet(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.model = models.resnet50(weights="DEFAULT")
        # Freeze all layers
        for param in self.model.parameters():
            param.requires_grad = False
        # Unfreeze layer4
        for param in self.model.layer4.parameters():
            param.requires_grad = True
        # Get input features of final layer
        in_features = self.model.fc.in_features
        # Replace fully connected layer
        self.model.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(in_features, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# %%
model=carclassifierresnet(num_classes=num_classes).to(device)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(filter(lambda p : p.requires_grad,model.parameters()),lr=0.001,weight_decay=1e-4)

# %%
all_labels,all_predictions=train_model(model,criterion,optimizer,epochs=5)
# Out:
# Batch:10, Epoch:1 ,loss:1.14
# Batch:20, Epoch:1 ,loss:0.77
# Batch:30, Epoch:1 ,loss:0.57
# Batch:40, Epoch:1 ,loss:0.70
# Batch:50, Epoch:1 ,loss:0.48
# epoch [1/5], Avg loss:0.9310
# Validation Accuracy: 61.11
# Batch:10, Epoch:2 ,loss:0.44
# Batch:20, Epoch:2 ,loss:0.40
# Batch:30, Epoch:2 ,loss:0.83
# Batch:40, Epoch:2 ,loss:0.43
# Batch:50, Epoch:2 ,loss:0.51
# epoch [2/5], Avg loss:0.5282
# Validation Accuracy: 77.60
# Batch:10, Epoch:3 ,loss:0.36
# Batch:20, Epoch:3 ,loss:0.26
# Batch:30, Epoch:3 ,loss:0.38
# Batch:40, Epoch:3 ,loss:0.42
# Batch:50, Epoch:3 ,loss:0.32
# epoch [3/5], Avg loss:0.3634
# Validation Accuracy: 77.95
# Batch:10, Epoch:4 ,loss:0.18
# Batch:20, Epoch:4 ,loss:0.16
# Batch:30, Epoch:4 ,loss:0.15
# Batch:40, Epoch:4 ,loss:0.50
# Batch:50, Epoch:4 ,loss:0.53
# epoch [4/5], Avg loss:0.2868
# Validation Accuracy: 77.43
# Batch:10, Epoch:5 ,loss:0.26
# Batch:20, Epoch:5 ,loss:0.11
# Batch:30, Epoch:5 ,loss:0.07
# Batch:40, Epoch:5 ,loss:0.36
# Batch:50, Epoch:5 ,loss:0.11
# epoch [5/5], Avg loss:0.2139
# Validation Accuracy: 80.56
# Execution time :540.7134420871735 seconds

# %% [markdown]
# ### HYper parameter tuning

# %% [raw]
# {'lr': 0.0013306375383660026, 'dropout_rate': 0.6729941640575401}

# %%
class carclassifierresnet(nn.Module):
    def __init__(self, num_classes,dropout_rate):
        super().__init__()
        self.model = models.resnet50(weights="DEFAULT")
        # Freeze all layers
        for param in self.model.parameters():
            param.requires_grad = False
        # Unfreeze layer4
        for param in self.model.layer4.parameters():
            param.requires_grad = True
        # Get input features of final layer
        in_features = self.model.fc.in_features
        # Replace fully connected layer
        self.model.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(in_features, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# %%
model=carclassifierresnet(num_classes=num_classes,dropout_rate=0.6).to(device)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(filter(lambda p : p.requires_grad,model.parameters()),lr=0.001,weight_decay=1e-4)
all_labels,all_predictions=train_model(model,criterion,optimizer,epochs=5)
# Out:
# Batch:10, Epoch:1 ,loss:0.97
# Batch:20, Epoch:1 ,loss:0.85
# Batch:30, Epoch:1 ,loss:0.53
# Batch:40, Epoch:1 ,loss:0.79
# Batch:50, Epoch:1 ,loss:0.66
# epoch [1/5], Avg loss:0.9097
# Validation Accuracy: 72.57
# Batch:10, Epoch:2 ,loss:0.36
# Batch:20, Epoch:2 ,loss:0.57
# Batch:30, Epoch:2 ,loss:0.47
# Batch:40, Epoch:2 ,loss:0.48
# Batch:50, Epoch:2 ,loss:0.50
# epoch [2/5], Avg loss:0.5244
# Validation Accuracy: 70.31
# Batch:10, Epoch:3 ,loss:0.36
# Batch:20, Epoch:3 ,loss:0.50
# Batch:30, Epoch:3 ,loss:0.40
# Batch:40, Epoch:3 ,loss:0.53
# Batch:50, Epoch:3 ,loss:0.39
# epoch [3/5], Avg loss:0.3715
# Validation Accuracy: 81.42
# Batch:10, Epoch:4 ,loss:0.23
# Batch:20, Epoch:4 ,loss:0.22
# Batch:30, Epoch:4 ,loss:0.07
# Batch:40, Epoch:4 ,loss:0.36
# Batch:50, Epoch:4 ,loss:0.48
# epoch [4/5], Avg loss:0.2884
# Validation Accuracy: 73.44
# Batch:10, Epoch:5 ,loss:0.23
# Batch:20, Epoch:5 ,loss:0.33
# Batch:30, Epoch:5 ,loss:0.09
# Batch:40, Epoch:5 ,loss:0.17
# Batch:50, Epoch:5 ,loss:0.28
# epoch [5/5], Avg loss:0.2463
# Validation Accuracy: 80.03
# Execution time :522.8770608901978 seconds

# %% [markdown]
# ### MODEL EVALUATION USING CONFUSION MATRIX AND CLASSIFICATION REPORT

# %%
report=classification_report(all_labels,all_predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       116
#            1       0.81      0.77      0.79       102
#            2       0.90      0.89      0.89       114
#            3       0.89      0.54      0.67        76
#            4       0.64      0.78      0.71        86
#            5       0.78      0.90      0.84        82
#
#     accuracy                           0.80       576
#    macro avg       0.81      0.79      0.79       576
# weighted avg       0.81      0.80      0.80       576

# %%
class_names=dataset.classes
cf=confusion_matrix(all_labels,all_predictions,labels=np.arange(num_classes))
disp=ConfusionMatrixDisplay(confusion_matrix=cf,display_labels=class_names)
disp.plot(cmap=plt.cm.Blues,xticks_rotation=45)
plt.title("Confusion Matrix for Vehicle Damage classification")
plt.show()

# %%
torch.save(model.state_dict(),"saved_model.pth")
